# %%
import pandas as pd
import numpy as np

# %%
M = pd.read_csv('MovieReviews.csv', index_col='Name')

# %%
M
# Out:
#                          American Sniper  \
# Name
# Mike                                 NaN
# HJ SONG                              NaN
# Ryan Hansen                          NaN
# Olumuyiwa Durojaiye                  NaN
# Charlie                              NaN
# Sina Tuy                             NaN
# Pavithra Shetty                      NaN
# Sara Collins                         NaN
# Jonathan Doll                        NaN
# saikiran reddy                         3
# Aishwarya reddy                      NaN
# Brant Mullinix                       NaN
# Sai Sampath                          NaN
# Suyendra                             NaN
# Sai Yallapragada                       5
# Akhilesh                             NaN
# Sundar Prasad                        NaN
# Evan Piercy                            4
# Jessica Fong                         NaN
# Onsiri Tapsarn                         3
# Anirudh Thota                        NaN
# Greg Werner                            5
# ...

# %%
def pearson(s1, s2):
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %%
recs = get_recs('The Fault in Our Stars', M, 10)

# %%
recs[:1]
# Out:
# [('How to Train your Dragon 2', 0.3528496583218998)]

# %%
#the movies I've seen
my_ratings = M.ix['Shiva rama raju Chekuri'].dropna()
#the movie I've rated the highest
my_ratings.sort(ascending=False)
#the name of the movie I've rated the highest
fav_movie = my_ratings.index[0]
# Out:
# /home/shiva/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting

# %%
fav_movie
# Out:
# 'Gone Girl'

# %%
recs = get_recs(fav_movie, M, 10)

# %%
recs[:10]
# Out:
# [('American Sniper', 0.41419165893675425),
#  ('Godzilla', 0.2794384025662679),
#  ('300: Rise of an Empire', 0.18306956528130916),
#  ('The Lego Movie', 0.12381486513556662),
#  ('Transformers', 0.12344876820018343),
#  ('How to Train your Dragon 2', 0.11037439416391988),
#  ('Divergent', 0.066669069718543361),
#  ('The Fault in Our Stars', 0.057295970912694054),
#  ('Interstellar', 0.01588633092697703),
#  ('Malificent', 0.0014628890979585846)]

# %% [markdown]
#  ## Movies that I haven't seen, predict how I would rate them using my class reviews?

# %%
not_rated = M.ix['Shiva rama raju Chekuri']
not_rated.sort()
for i in range(0, not_rated.count(), 1):
    not_rated.drop(not_rated.index[0], inplace=True)
# Out:
# /home/shiva/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting
#   from ipykernel import kernelapp as app

# %%
not_rated
# Out:
# Big Hero 6               NaN
# Divergent                NaN
# The Fault in Our Stars   NaN
# Unbroken                 NaN
# Name: Shiva rama raju Chekuri, dtype: float64

# %%
print "Pearson Correlation coefficient of :"
a= []
for i in range(0, M.shape[0], 1): 
    cor=pearson(M.ix[53], M.ix[i])
    print "(" + M.index[53] + " , " + M.index[i] + ") :", cor
    a.append(cor)
# Out:
# Pearson Correlation coefficient of :
# (Shiva rama raju Chekuri , Mike) : -0.0152676204138
# (Shiva rama raju Chekuri , HJ SONG) : 0.323718470771
# (Shiva rama raju Chekuri , Ryan Hansen) : -0.204212491544
# (Shiva rama raju Chekuri , Olumuyiwa Durojaiye) : 0.321393540137
# (Shiva rama raju Chekuri , Charlie) : 0.211564039953
# (Shiva rama raju Chekuri , Sina Tuy) : -0.0387104830569
# (Shiva rama raju Chekuri , Pavithra Shetty) : 0.236188746487
# (Shiva rama raju Chekuri , Sara Collins) : 0.0
# (Shiva rama raju Chekuri , Jonathan Doll) : -0.312093891966
# (Shiva rama raju Chekuri , saikiran reddy) : 0.303580814465
# (Shiva rama raju Chekuri , Aishwarya reddy) : 0.658088753954
# (Shiva rama raju Chekuri , Brant Mullinix) : -0.183702358379
# (Shiva rama raju Chekuri , Sai Sampath) : 0.658088753954
# (Shiva rama raju Chekuri , Suyendra) : -0.187748859083
# (Shiva rama raju Chekuri , Sai Yallapragada) : 0.239356776939
# (Shiva rama raju Chekuri , Akhilesh) : 0.169256677167
# ...

# %%
def pred_rate(x, a):
    """
    predicted rate is calculated as rate= (x[0]*a[0] + x[1]*a[1] +...+x[i]*a[i]) / (a[0]+a[1]+..+a[i]) 
    returns predicted rate 
    """
    j=0
    k=0
    for i in range(0, x.shape[0], 1):
        if x.irow(i)>0 and a[i]>0: 
            j= j+(a[i]*x.irow(i))
            k= k+a[i]
        else:
            continue
    return j/k

# %%
print "My ratings for the movies that I have not seen using class review:"
for i in range(0, not_rated.shape[0], 1): 
    x=M[not_rated.index[i]]
    rate=pred_rate(x, a)
    print not_rated.index[i] +": ", rate.round(1)
# Out:
# My ratings for the movies that I have not seen using class review:
# Big Hero 6:  4.0
# Divergent:  3.1
# The Fault in Our Stars:  3.8
# Unbroken:  4.1
# /home/shiva/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: irow(i) is deprecated. Please use .iloc[i] or .iat[i]
# /home/shiva/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: irow(i) is deprecated. Please use .iloc[i] or .iat[i]
